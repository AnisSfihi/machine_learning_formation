# %%
import numpy as np 
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x, y =make_regression(n_samples=100, n_features=1, noise=10)

# %%
plt.scatter(x, y)

# %%
print(x.shape)
y=y.reshape(y.shape[0], 1)
print(y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
X=np.hstack((x, np.ones(x.shape)))
print(X)
# Out:
# [[-1.59590448e+00  1.00000000e+00]
#  [-3.64639062e-02  1.00000000e+00]
#  [-5.36291836e-01  1.00000000e+00]
#  [ 3.49984569e-01  1.00000000e+00]
#  [-4.96451415e-01  1.00000000e+00]
#  [ 9.78758060e-01  1.00000000e+00]
#  [ 1.45773859e+00  1.00000000e+00]
#  [ 2.77867825e-01  1.00000000e+00]
#  [-1.08048547e+00  1.00000000e+00]
#  [-1.04254726e+00  1.00000000e+00]
#  [-9.27433743e-02  1.00000000e+00]
#  [-1.73524893e+00  1.00000000e+00]
#  [-1.55966520e+00  1.00000000e+00]
#  [ 1.31307845e-01  1.00000000e+00]
#  [ 1.38503674e+00  1.00000000e+00]
#  [-1.61675379e+00  1.00000000e+00]
#  [ 6.90981154e-02  1.00000000e+00]
#  [ 2.42942612e+00  1.00000000e+00]
#  [-4.59982429e-01  1.00000000e+00]
#  [ 1.22983720e+00  1.00000000e+00]
#  [-1.17810021e+00  1.00000000e+00]
#  [-6.29457150e-01  1.00000000e+00]
#  [-1.58882814e+00  1.00000000e+00]
#  [-4.06590002e-01  1.00000000e+00]
#  [-1.24826437e+00  1.00000000e+00]
#  [-1.48555614e+00  1.00000000e+00]
#  [-1.28947104e-01  1.00000000e+00]
#  [ 7.52377521e-01  1.00000000e+00]
#  [ 6.03296717e-01  1.00000000e+00]
#  [ 2.22245611e-01  1.00000000e+00]
#  [ 6.59687098e-01  1.00000000e+00]
#  [-5.21426556e-01  1.00000000e+00]
#  [-5.98835874e-01  1.00000000e+00]
#  [-8.44171136e-01  1.00000000e+00]
#  [ 4.78142238e-01  1.00000000e+00]
#  [-1.69446549e+00  1.00000000e+00]
#  [-1.04134844e+00  1.00000000e+00]
#  [ 1.96598156e-01  1.00000000e+00]
#  [ 4.82033712e-01  1.00000000e+00]
#  [ 5.88450168e-01  1.00000000e+00]
#  [-1.19522265e+00  1.00000000e+00]
#  [-1.14295374e+00  1.00000000e+00]
#  [-6.17628436e-01  1.00000000e+00]
#  [ 9.65357144e-02  1.00000000e+00]
#  [-6.96407426e-01  1.00000000e+00]
#  [-2.47386929e-01  1.00000000e+00]
#  [ 6.23887626e-01  1.00000000e+00]
#  [-1.53861154e+00  1.00000000e+00]
#  [-2.01289421e+00  1.00000000e+00]
#  [-1.06832719e+00  1.00000000e+00]
#  [ 4.92872572e-01  1.00000000e+00]
#  [ 2.17101644e+00  1.00000000e+00]
#  [-1.29702652e+00  1.00000000e+00]
#  [-1.04605426e+00  1.00000000e+00]
#  [ 1.02118888e+00  1.00000000e+00]
#  [-6.08623357e-01  1.00000000e+00]
#  [ 8.52698336e-01  1.00000000e+00]
#  [-7.16628003e-05  1.00000000e+00]
#  [ 7.12422055e-01  1.00000000e+00]
#  [ 5.78977757e-01  1.00000000e+00]
#  [-8.78684539e-03  1.00000000e+00]
#  [ 7.26321291e-01  1.00000000e+00]
#  [ 2.26794540e+00  1.00000000e+00]
#  [ 9.31463874e-02  1.00000000e+00]
#  [-4.36495159e-01  1.00000000e+00]
#  [ 4.49337969e-01  1.00000000e+00]
#  [-1.25698370e-01  1.00000000e+00]
#  [-5.08504951e-01  1.00000000e+00]
#  [-1.39923724e-01  1.00000000e+00]
#  [ 8.02476727e-01  1.00000000e+00]
#  [-8.12023620e-01  1.00000000e+00]
#  [-2.77908457e-01  1.00000000e+00]
#  [-6.94641656e-01  1.00000000e+00]
#  [ 5.50745931e-01  1.00000000e+00]
#  [-4.26876250e-01  1.00000000e+00]
#  [-1.47013078e+00  1.00000000e+00]
#  [ 3.90593478e-01  1.00000000e+00]
#  [-2.66266366e-01  1.00000000e+00]
#  [ 1.69698011e-01  1.00000000e+00]
#  [-7.76196944e-02  1.00000000e+00]
#  [-2.38663025e-01  1.00000000e+00]
#  [ 1.02024751e+00  1.00000000e+00]
#  [-2.86414370e-01  1.00000000e+00]
#  [ 9.77169150e-01  1.00000000e+00]
#  [-1.37918176e+00  1.00000000e+00]
#  [ 1.45955129e+00  1.00000000e+00]
#  [-9.41349948e-01  1.00000000e+00]
#  [-3.87816276e-01  1.00000000e+00]
#  [-1.23562884e+00  1.00000000e+00]
#  [-2.11663918e+00  1.00000000e+00]
#  [ 2.40767081e-01  1.00000000e+00]
#  [ 1.41378216e-01  1.00000000e+00]
#  [-8.27262289e-01  1.00000000e+00]
#  [ 7.62906228e-01  1.00000000e+00]
#  [-6.24122709e-01  1.00000000e+00]
#  [-3.45868050e-01  1.00000000e+00]
#  [-1.62349178e+00  1.00000000e+00]
#  [-5.06128874e-02  1.00000000e+00]
#  [ 5.75432549e-01  1.00000000e+00]
#  [ 2.39271396e+00  1.00000000e+00]]

# %%
teta = np.random.randn(2, 1)
print(teta.shape)
# Out:
# (2, 1)

# %%
def model(X, teta):
    return X.dot(teta)

# %%
plt.scatter(x, y)
plt.plot(x, model(X, teta), c='r')
plt.scatter(x, model(X,teta), c='r')

# %%
def cost_function(X, y, teta):
    m=len(y)
    return 1/(2*m) * np.sum((model(X, teta)-y)**2)

# %%
def grad(X, y, teta):
    m=len(y)
    return 1/m * X.T.dot(model(X, teta)-y)

# %%
def gradient_descent(X, y, teta, alpha, n_iterations):
    cost_history = np.zeros(n_iterations)
    for i in range(0, n_iterations):
        teta = teta - alpha*grad(X, y, teta)
        cost_history[i] = cost_function(X, y, teta)
    return teta, cost_history

# %%
teta_final, cost_history = gradient_descent(X, y, teta, alpha=0.01, n_iterations=1000)

# %%
predictions = model(X, teta_final)
plt.scatter(x,y)
plt.plot(x,predictions, c='r')

# %%
plt.plot(range(1000), cost_history)

# %%
def coef_determination(y, pred):
    u = ((y-pred)**2).sum()
    v = ((y-y.mean())**2).sum()
    return 1- u/v

coef_determination(y, predictions)
# Out:
# 0.8789477864633525
